# %% [markdown]
# <a href="https://colab.research.google.com/github/benoynoel/Fortnite2.github.io/blob/master/Hypothesis_Testing_Assignment(ANOVA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Libraries

# %%
import pandas as pd
import scipy
from scipy import stats

# %% [markdown]
# #Data

# %%
df = pd.read_csv("LabTAT.csv")
df
# Out:
#      Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0          185.35        165.53        176.70        166.13
# 1          170.49        185.91        198.45        160.79
# 2          192.77        194.92        201.23        185.18
# 3          177.33        183.00        199.61        176.42
# 4          193.41        169.57        204.63        152.60
# ..            ...           ...           ...           ...
# 115        178.49        170.66        193.80        172.68
# 116        176.08        183.98        215.25        177.64
# 117        202.48        174.54        203.99        170.27
# 118        182.40        197.18        194.52        150.87
# 119        182.09        215.17        221.49        162.21
#
# [120 rows x 4 columns]

# %%
Laboratory_1 = df['Laboratory 1']
Laboratory_2 = df['Laboratory 2']
Laboratory_3 = df['Laboratory 3']
Laboratory_4 = df['Laboratory 4']

# %% [markdown]
# #F-statisctiacl & P-value

# %%
stats.f_oneway(Laboratory_1, Laboratory_2, Laboratory_3, Laboratory_4)
# Out:
# F_onewayResult(statistic=118.70421654401437, pvalue=2.1156708949992414e-57)

# %% [markdown]
# P-value > Alpha value i.e., 2.1156 > 0.05
# Hence there is no siginicant difference in the average TAT among the laboratories
